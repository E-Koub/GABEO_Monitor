# %% [markdown]
# import pandas as pd
# df = pd.read_csv('../data/processed/automates_prepared.csv', sep=';')
# df.head()
# df.info()
# df.describe()

# %%
Variables catégorielles

# %%
df['quartier'].value_counts().plot(kind='barh')
df['Typologie'].value_counts().plot(kind='bar')
df['Etat de fonctionnement'].value_counts(normalize=True)
# Out:
# Etat de fonctionnement
# disponible                       0.927097
# hors service                     0.035793
# service dégradé                  0.033158
# suspendu                         0.003513
# en attente de désinstallation    0.000220
# en attente d'activation          0.000220
# Name: proportion, dtype: float64

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[48.85, 2.35], zoom_start=6)
mc = MarkerCluster().add_to(m)
for _, row in df.iterrows():
    folium.Marker(location=[row['latitude'], row['longitude']],
                  popup=f"{row['Agence']} - {row['quartier']}").add_to(mc)
m
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import folium
#       2 from folium.plugins import MarkerCluster
#       4 m = folium.Map(location=[48.85, 2.35], zoom_start=6)
#
# ModuleNotFoundError: No module named 'folium'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Nettoyage rapide
df_clean = df.dropna(subset=['score_performance'])

print(df_clean['quartier'].value_counts())
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.sort_values('score_performance').head(10)
# Out:
#   Réseau  Code Etablissement      Etablissement  Code agence  \
# 0     BP               10207  Bp Rives De Paris          117
# 1     BP               10207  Bp Rives De Paris           87
# 2     BP               10207  Bp Rives De Paris           23
# 3     BP               10207  Bp Rives De Paris           58
# 4     CE               17515   Ce Ile-De-France          260
# 5     CE               17515   Ce Ile-De-France          260
# 6     CE               17515   Ce Ile-De-France          130
# 7     BP               10548   Banque De Savoie         3000
# 8     BP               16607             Bp Sud         7290
# 9     BP               10207  Bp Rives De Paris        10207
#
#                                Agence                      Adresse  \
# 0                       Diderot/00117          80 AVENUE DE FRANCE
# 1                         Odeon/00087  110 BOULEVARD SAINT GERMAIN
# 2                     Plaisance/00023           47 RUE DE GERGOVIE
# ...
